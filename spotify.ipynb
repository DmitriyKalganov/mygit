# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
df = pd.read_csv('df_complete.csv')

# %%
df.head()
# Out:
#                 track_uri                       track         artist  \
# 0  6DCZcSspjsKoFjzjrWoCdn                  God's Plan          Drake
# 1  0e7ipj03S05BNilyu5bRzt  rockstar (feat. 21 Savage)    Post Malone
# 2  09mEdoA6zrmBPgTEN5qXmN            Call Out My Name     The Weeknd
# 3  0u2P5u6lvoDfwTYjAADbn4        lovely (with Khalid)  Billie Eilish
# 4  7ef4DlsgrMEH11cDZd32M6    One Kiss (with Dua Lipa)  Calvin Harris
#
#    artist_popularity  followers  \
# 0                 97   70260570
# 1                 89   39233698
# 2                 96   55208147
# 3                 89   73989789
# 4                 85   23066688
#
#                                         artist_genre  track_popularity  \
# 0  ['canadian hip hop', 'canadian pop', 'hip hop'...                83
# 1                  ['dfw rap', 'melodic rap', 'rap']                83
# 2  ['canadian contemporary r&b', 'canadian pop', ...                88
# ...

# %%
con = sqlite3.connect('db')

# %%
df.to_sql('spotify',con,index=False,if_exists='replace')
# Out:
# 500

# %%
def select(sql):
    return pd.read_sql(sql,con)

# %%
sql = '''select artist,artist_popularity,year from spotify
where artist = 'Bad Bunny'

'''

# %%
select(sql)
# Out:
#       artist  artist_popularity  year
# 0  Bad Bunny                100  2019
# 1  Bad Bunny                100  2019
# 2  Bad Bunny                100  2020
# 3  Bad Bunny                100  2020
# 4  Bad Bunny                100  2021
# 5  Bad Bunny                100  2021
# 6  Bad Bunny                100  2021
# 7  Bad Bunny                100  2022
# 8  Bad Bunny                100  2022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_uri          500 non-null    object
#  1   track              500 non-null    object
#  2   artist             500 non-null    object
#  3   artist_popularity  500 non-null    int64
#  4   followers          500 non-null    int64
#  5   artist_genre       500 non-null    object
#  6   track_popularity   500 non-null    int64
#  7   album              500 non-null    object
#  8   year               500 non-null    int64
#  9   danceability       500 non-null    float64
#  10  valence            500 non-null    float64
#  11  energy             500 non-null    float64
#  12  tempo              500 non-null    float64
#  13  loudness           500 non-null    float64
#  14  speechiness        500 non-null    float64
#  15  instrumentalness   500 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['track_uri', 'track', 'artist', 'artist_popularity', 'followers',
#        'artist_genre', 'track_popularity', 'album', 'year', 'danceability',
#        'valence', 'energy', 'tempo', 'loudness', 'speechiness',
#        'instrumentalness', 'liveness', 'acousticness', 'key'],
#       dtype='object')

# %%
sql = '''select artist,track,year,max(artist_popularity) as pp from spotify
group by year
order by year DESC
'''

# %% [markdown]
# **Most popular artist by years**

# %%
select(sql)
# Out:
#          artist             track  year   pp
# 0     Bad Bunny  Tití Me Preguntó  2022  100
# 1     Bad Bunny            DÁKITI  2021  100
# 2     Bad Bunny            DÁKITI  2020  100
# 3     Bad Bunny          Callaita  2019  100
# 4  Taylor Swift          Delicate  2018   99

# %%
sql = '''select artist,year,max(track_popularity) as pp2,min(track_popularity) as pp from spotify
group by year
order by year DESC
'''

# %%
select(sql)
# Out:
#                 artist  year  pp2  pp
# 0          Nicky Youre  2022   98   6
# 1                Lorde  2021   90   1
# 2                  BTS  2020   88   0
# 3  5 Seconds of Summer  2019   88  67
# 4              Cardi B  2018   88  67

# %%
sql = '''select * from spotify
where artist = 'Sam Smith' and year = 2022
order by track_popularity DESC'''

# %%
select(sql)
# Out:
#                 track_uri                      track     artist  \
# 0  3nqQXoyQOWXiESFLlDF1hG  Unholy (feat. Kim Petras)  Sam Smith
#
#    artist_popularity  followers       artist_genre  track_popularity  \
# 0                 89   21167020  ['pop', 'uk pop']                98
#
#                        album  year  danceability  valence  energy    tempo  \
# 0  Unholy (feat. Kim Petras)  2022         0.714    0.238   0.472  131.121
#
#    loudness  speechiness  instrumentalness  liveness  acousticness  key
# 0    -7.375       0.0864          0.000005     0.266         0.013    2
